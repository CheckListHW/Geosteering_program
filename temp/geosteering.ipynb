# %%
from Geosteering_model import *

# %%
xml_path = 'input/old/old.xml'
GR_path = 'input/old/old.las'

model = Geostering_Model(xml_path=xml_path,
                         GR_path=GR_path)

# %%
model.start_complex_geosteering(min_interp_seg_size=0, # используется при наличии имиджей
                                delta_deg=5, 
                                st=1, metric='mae', 
                                plot_matching=False,
                                without_dips_nof=4)  # используется при отсутствии имиджей
# Out:
# c:\Users\SalnikovMA\PycharmProjects\Auto_Geosteering\Geosteering_with_images\Geosteering_model.py:543: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_x_y = top_x_y.append(markers_top)

# %%
model.surfaces_visualization(n=32000)
model.curve_matching_visualization()

# %%
model.save_results_to_xml()
